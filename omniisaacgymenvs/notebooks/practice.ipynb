# %%
import getpass

user = getpass.getuser()
from omni.isaac.kit import SimulationApp

user_dir = f"omniverse://localhost/Users/{user}"

try:
    simulation_app.close()
except NameError:
    simulation_app = SimulationApp({"livesync_usd": f"{user_dir}/temp_jupyter_stage.usd"})
# Out:
# Starting kit application with the following args:  ['/home/ksterx/.local/share/ov/pkg/isaac_sim-2022.2.0/exts/omni.isaac.kit/omni/isaac/kit/simulation_app.py', '/home/ksterx/.local/share/ov/pkg/isaac_sim-2022.2.0/apps/omni.isaac.sim.python.kit', '--/app/tokens/exe-path=/home/ksterx/.local/share/ov/pkg/isaac_sim-2022.2.0/kit', '--/persistent/app/viewport/displayOptions=3094', '--/rtx/materialDb/syncLoads=True', '--/rtx/hydra/materialSyncLoads=True--/omni.kit.plugin/syncUsdLoads=True', '--/app/renderer/resolution/width=1280', '--/app/renderer/resolution/height=720', '--/app/window/width=1440', '--/app/window/height=900', '--/renderer/multiGpu/enabled=True', '--/app/fastShutdown=False', '--ext-folder', '/home/ksterx/.local/share/ov/pkg/isaac_sim-2022.2.0/exts', '--ext-folder', '/home/ksterx/.local/share/ov/pkg/isaac_sim-2022.2.0/apps', '--/physics/cudaDevice=0', '--portable', '--no-window']
# Passing the following args to the base kit application:  ['-f', '/home/ksterx/.local/share/jupyter/runtime/kernel-6d48abbe-aa17-4468-94eb-26d5e61de8e6.json']
# [Warning] [omni.isaac.kit.simulation_app] Modules: ['omni', 'omni.kit.app._impl.telemetry_helpers'] were loaded before SimulationApp was started and might not be loaded correctly.
# [Warning] [omni.isaac.kit.simulation_app] Please check to make sure no extra omniverse or pxr modules are imported before the call to SimulationApp(...)
# [Warning] [omni.isaac.kit.simulation_app] fast shutdown not supported with jupyter notebooks
# [Warning] [omni.kit.app.plugin] No crash reporter present, dumps uploading isn't available.
# [Info] [carb] Logging to file: /home/ksterx/.local/share/ov/pkg/isaac_sim-2022.2.0/kit/logs/Kit/Isaac-Sim/2022.2/kit_20230316_054342.log
# 2023-03-15 20:43:42 s] [Warning] [omni.ext.plugin] [ext: omni.drivesim.sensors.nv.radar] Extensions config 'extension.toml' doesn't exist '/home/ksterx/.local/share/ov/pkg/isaac_sim-2022.2.0/exts/omni.drivesim.sensors.nv.radar' or '/home/ksterx/.local/share/ov/pkg/isaac_sim-2022.2.0/exts/omni.drivesim.sensors.nv.radar/config'
# 2023-03-15 20:43:42 s] [Warning] [omni.ext.plugin] [ext: omni.drivesim.sensors.nv.lidar] Extensions config 'extension.toml' doesn't exist '/home/ksterx/.local/share/ov/pkg/isaac_sim-2022.2.0/exts/omni.drivesim.sensors.nv.lidar' or '/home/ksterx/.local/share/ov/pkg/isaac_sim-2022.2.0/exts/omni.drivesim.sensors.nv.lidar/config'
# [0.155s] [ext: omni.stats-0.0.0] startup
# [0.173s] [ext: omni.rtx.shadercache-1.0.0] startup
# [0.176s] [ext: omni.assets.plugins-0.0.0] startup
# [0.177s] [ext: omni.gpu_foundation-0.0.0] startup
# 2023-03-15 20:43:42 s] [Warning] [carb] FrameworkImpl::setDefaultPlugin(client: omni.gpu_foundation_factory.plugin, desc : [carb::graphics::Graphics v2.11], plugin : carb.graphics-vulkan.plugin) failed. Plugin selection is locked, because the interface was previously acquired by:
# [0.183s] [ext: carb.windowing.plugins-1.0.0] startup
# [0.189s] [ext: omni.kit.renderer.init-0.0.0] startup
#
# |---------------------------------------------------------------------------------------------|
# | Driver Version: 515.65.1      | Graphics API: Vulkan
# |=============================================================================================|
# | GPU | Name                             | Active | LDA | GPU Memory | Vendor-ID | LUID       |
# |     |                                  |        |     |            | Device-ID | UUID       |
# |---------------------------------------------------------------------------------------------|
# | 0   | NVIDIA GeForce RTX 3060          | Yes: 0 |     | 12534   MB | 10de      | 0          |
# |     |                                  |        |     |            | 2504      | ffe8fb09.. |
# |=============================================================================================|
# | OS: Linux home-ubuntu, Version: 5.19.0-35-generic
# | XServer Vendor: The X.Org Foundation, XServer Version: 12101003 (1.21.1.3)
# | Processor: 12th Gen Intel(R) Core(TM) i7-12700 | Cores: Unknown | Logical: 20
# |---------------------------------------------------------------------------------------------|
# | Total Memory (MB): 31839 | Free Memory: 16991
# | Total Page/Swap (MB): 2047 | Free Page/Swap: 2047
# |---------------------------------------------------------------------------------------------|
# [0.685s] [ext: omni.kit.pipapi-0.0.0] startup
# [0.689s] [ext: omni.kit.pip_archive-0.0.0] startup
# [0.695s] [ext: omni.kit.loop-isaac-1.0.0] startup
# [0.695s] [ext: omni.kit.async_engine-0.0.0] startup
# [0.697s] [ext: omni.kit.test-0.0.0] startup
# [0.722s] [ext: omni.usd.config-1.0.0] startup
# [0.727s] [ext: omni.usd.libs-1.0.0] startup
# [0.822s] [ext: omni.isaac.core_archive-2.0.1] startup
# [0.910s] [ext: omni.pip.torch-1_13_0-0.1.4] startup
# [0.915s] [ext: omni.isaac.ml_archive-1.1.0] startup
# [1.092s] [ext: omni.client-0.1.1] startup
# [1.121s] [ext: omni.appwindow-1.0.1] startup
# [1.124s] [ext: omni.kit.renderer.core-0.0.0] startup
# [1.127s] [ext: omni.kit.renderer.capture-0.0.0] startup
# [1.130s] [ext: omni.kit.renderer.imgui-0.0.0] startup
# [1.175s] [ext: carb.audio-0.1.0] startup
# [1.177s] [ext: omni.ui-2.12.23] startup
# [1.186s] [ext: omni.uiaudio-1.0.0] startup
# [1.187s] [ext: omni.kit.mainwindow-1.0.0] startup
# [1.190s] [ext: omni.kit.uiapp-0.0.0] startup
# [1.190s] [ext: omni.usd.schema.physics-1.0.0] startup
# [1.226s] [ext: omni.usd.schema.omniscripting-1.0.0] startup
# [1.235s] [ext: omni.usd.schema.audio-0.0.0] startup
# [1.244s] [ext: omni.usd.schema.semantics-0.0.0] startup
# [1.255s] [ext: omni.usd.schema.anim-0.0.0] startup
# [1.324s] [ext: omni.usd.schema.omnigraph-1.0.0] startup
# [1.332s] [ext: omni.usd.schema.geospatial-0.0.0] startup
# [1.341s] [ext: omni.usd.core-1.0.0] startup
# [1.344s] [ext: omni.gpucompute.plugins-0.0.0] startup
# [1.345s] [ext: omni.timeline-1.0.5] startup
# [1.347s] [ext: omni.kit.audiodeviceenum-1.0.0] startup
# [1.349s] [ext: omni.hydra.usdrt_delegate-4.1.1] startup
# [1.363s] [ext: omni.kit.window.popup_dialog-2.0.15] startup
# [1.369s] [ext: omni.kit.actions.core-1.0.0] startup
# [1.372s] [ext: omni.kit.widget.nucleus_connector-1.0.2] startup
# [1.375s] [ext: omni.kit.commands-1.4.5] startup
# [1.380s] [ext: omni.hydra.scene_delegate-0.3.0] startup
# [1.385s] [ext: omni.usd-1.6.23] startup
# [1.424s] [ext: omni.kit.asset_converter-1.2.39] startup
# [1.433s] [ext: omni.usd.schema.physx-0.0.0] startup
# [1.458s] [ext: omni.usd.schema.isaac-1.0.0] startup
# [1.474s] [ext: omni.usd.schema.forcefield-0.0.0] startup
# [1.482s] [ext: omni.kit.collaboration.channel_manager-1.0.9] startup
# [1.484s] [ext: omni.inspect-1.0.1] startup
# [1.489s] [ext: omni.kit.menu.utils-1.4.7] startup
# [1.497s] [ext: omni.kit.usd.layers-2.0.10] startup
# [1.504s] [ext: omni.graph.core-2.64.7] startup
# [1.507s] [ext: omni.iray.libs-0.0.0] startup
# [1.510s] [ext: omni.kit.primitive.mesh-1.0.6] startup
# [1.513s] [ext: omni.volume-0.1.0] startup
# [1.516s] [ext: omni.mdl.neuraylib-0.1.0] startup
# [1.520s] [ext: omni.kit.stage_templates-1.1.11] startup
# [1.521s] [ext: omni.graph.tools-1.17.0] startup
# [1.535s] [ext: omni.hydra.rtx-0.1.0] startup
# [1.542s] [ext: omni.kit.usd_undo-0.1.1] startup
# [1.544s] [ext: omni.ui.scene-1.5.17] startup
# [1.550s] [ext: omni.graph-1.50.1] startup
# [1.584s] [ext: omni.debugdraw-0.1.1] startup
# [1.589s] [ext: omni.hydra.engine.stats-1.0.0] startup
# [1.594s] [ext: omni.kit.search_core-1.0.1] startup
# [1.596s] [ext: omni.kit.widget.path_field-2.0.4] startup
# [1.597s] [ext: omni.kit.widget.versioning-1.3.8] startup
# [1.598s] [ext: omni.kit.widget.filebrowser-2.3.8] startup
# [1.616s] [ext: omni.kit.widget.browser_bar-2.0.4] startup
# [1.617s] [ext: omni.kit.notification_manager-1.0.4] startup
# [1.619s] [ext: omni.kvdb-0.0.0] startup
# [1.622s] [ext: omni.kit.window.filepicker-2.7.8] startup
# OmniAssetFileFormat
# [1.668s] [ext: omni.kit.viewport.registry-104.0.2] startup
# [1.671s] [ext: omni.kit.window.file_importer-1.0.8] startup
# [1.671s] [ext: omni.hydra.pxr-1.1.2] startup
# [1.675s] [ext: omni.mdl-0.1.0] startup
# [1.740s] [ext: omni.kit.clipboard-1.0.0] startup
# [1.741s] [ext: omni.activity.core-1.0.1] startup
# [1.746s] [ext: omni.kit.hydra_texture-1.0.11] startup
# [1.754s] [ext: omni.kit.material.library-1.3.21] startup
# [1.760s] [ext: omni.kit.menu.create-1.0.8] startup
# [1.761s] [ext: omni.kit.window.drop_support-1.0.1] startup
# [1.762s] [ext: omni.kit.widget.viewport-104.1.15] startup
# [1.764s] [ext: omni.kit.viewport.legacy_gizmos-1.0.8] startup
# [1.767s] [ext: omni.kit.context_menu-1.5.10] startup
# [1.771s] [ext: omni.kit.viewport.window-104.1.18] startup
# 2023-03-15 20:43:43 [1,768ms] [Warning] [omni.kit.ui.editor_menu] set_value menu Window/Viewport/Viewport 1 not found
# [1.798s] [ext: omni.localcache-0.0.0] startup
# [1.801s] [ext: omni.kit.window.viewport-0.0.0] startup
# [2.510s] [ext: omni.convexdecomposition-104.1.6-5.1] startup
# [2.514s] [ext: omni.kit.viewport.utility-1.0.12] startup
# [2.515s] [ext: omni.kit.window.file_exporter-1.0.10] startup
# [2.516s] [ext: omni.ui_query-1.1.1] startup
# [2.519s] [ext: omni.kit.window.file-1.3.30] startup
# [2.521s] [ext: omni.kit.window.content_browser_registry-0.0.1] startup
# [2.522s] [ext: omni.kit.ui_test-1.2.9] startup
# [2.525s] [ext: omni.kit.window.property-1.8.2] startup
# [2.527s] [ext: omni.kit.window.content_browser-2.6.5] startup
# [2.536s] [ext: omni.kit.widget.stage-2.7.18] startup
# [2.540s] [ext: omni.usdphysics-104.1.6-5.1] startup
# [2.542s] [ext: omni.kit.property.usd-3.18.12] startup
# [2.551s] [ext: omni.physx-104.1.6-5.1] startup
# [2.568s] [ext: omni.kit.widget.settings-1.0.1] startup
# [2.570s] [ext: omni.kit.widget.graph-1.5.3] startup
# [2.591s] [ext: omni.kit.widget.text_editor-1.0.2] startup
# [2.592s] [ext: omni.kit.window.preferences-1.3.7] startup
# [2.627s] [ext: omni.kit.window.extensions-1.1.1] startup
# [2.631s] [ext: omni.kit.widget.prompt-1.0.4] startup
# [2.632s] [ext: omni.physics.tensors-0.1.0] startup
# [2.640s] [ext: omni.graph.ui-1.24.1] startup
# [2.670s] [ext: omni.isaac.version-1.0.0] startup
# [2.671s] [ext: omni.physx.tensors-0.1.0] startup
# [2.678s] [ext: omni.graph.action-1.31.0] startup
# [2.685s] [ext: omni.kit.numpy.common-0.1.0] startup
# [2.688s] [ext: omni.kit.graph.delegate.default-1.0.18] startup
# [2.691s] [ext: omni.kit.widget.searchfield-1.0.8] startup
# [2.692s] [ext: omni.isaac.dynamic_control-1.2.2] startup
# [2.739s] [ext: omni.kit.manipulator.viewport-104.0.7] startup
# [2.740s] [ext: omni.kit.graph.editor.core-1.4.7] startup
# [2.742s] [ext: omni.isaac.core-1.42.0] startup
# [3.402s] [ext: omni.graph.visualization.nodes-2.0.0] startup
# [3.407s] [ext: omni.kit.graph.widget.variables-2.0.4] startup
# [3.408s] [ext: omni.isaac.ui-0.4.3] startup
# [3.410s] [ext: omni.isaac.isaac_sensor-2.0.0] startup
# 2023-03-15 20:43:45 [3,403ms] [Warning] [omni.isaac.isaac_sensor] omni.isaac.isaac_sensor is deprecated and was renamed; use omni.isaac.sensor
# [3.410s] [ext: omni.isaac.surface_gripper-0.3.2] startup
# 2023-03-15 20:43:45 [3,406ms] [Warning] [omni.kit.menu.utils.scripts.builder_utils] ********************* MenuItemDescription Surface Gripper *********************
# 2023-03-15 20:43:45 [3,406ms] [Warning] [omni.kit.menu.utils.scripts.builder_utils] Surface Gripper uses onclick_fn and/or unclick_fn which are deprecated. Use onclick_action and unclick_action instead which use omni.kit.actions.core
# [3.414s] [ext: omni.kit.graph.usd.commands-1.2.0] startup
# [3.415s] [ext: omni.kit.graph.delegate.modern-1.6.4] startup
# [3.417s] [ext: omni.isaac.manipulators-1.1.0] startup
# [3.418s] [ext: omni.graph.window.core-1.41.0] startup
# [3.426s] [ext: omni.isaac.mjcf-0.3.0] startup
# 2023-03-15 20:43:45 [3,425ms] [Warning] [omni.kit.menu.utils.scripts.builder_utils] ********************* MenuItemDescription MJCF Importer *********************
# 2023-03-15 20:43:45 [3,425ms] [Warning] [omni.kit.menu.utils.scripts.builder_utils] MJCF Importer uses onclick_fn and/or unclick_fn which are deprecated. Use onclick_action and unclick_action instead which use omni.kit.actions.core
# [3.432s] [ext: omni.graph.window.generic-1.3.10] startup
# 2023-03-15 20:43:45 [3,426ms] [Warning] [omni.kit.menu.utils.scripts.builder_utils] ********************* MenuItemDescription Push Graph *********************
# 2023-03-15 20:43:45 [3,426ms] [Warning] [omni.kit.menu.utils.scripts.builder_utils] Push Graph uses onclick_fn and/or unclick_fn which are deprecated. Use onclick_action and unclick_action instead which use omni.kit.actions.core
# 2023-03-15 20:43:45 [3,426ms] [Warning] [omni.kit.menu.utils.scripts.builder_utils] ********************* MenuItemDescription Lazy Graph *********************
# 2023-03-15 20:43:45 [3,426ms] [Warning] [omni.kit.menu.utils.scripts.builder_utils] Lazy Graph uses onclick_fn and/or unclick_fn which are deprecated. Use onclick_action and unclick_action instead which use omni.kit.actions.core
# [3.434s] [ext: omni.kit.widget.spinner-1.0.4] startup
# [3.434s] [ext: omni.kit.window.cursor-1.1.1] startup
# [3.435s] [ext: omni.isaac.lula-1.2.1] startup
# [3.452s] [ext: omni.graph.nodes-1.48.3] startup
# [3.463s] [ext: omni.kit.viewport.menubar.core-104.4.1] startup
# [3.485s] [ext: omni.isaac.motion_planning-0.2.1] startup
# [3.492s] [ext: omni.kit.widget.zoombar-1.0.4] startup
# [3.493s] [ext: omni.syntheticdata-0.2.4] startup
# 2023-03-15 20:43:45 [3,500ms] [Warning] [omni.kit.viewport.menubar.core.menu_item.viewport_menu_item] ViewportMenuItem order argument is deprecated, use order_setting_path
# [3.511s] [ext: omni.isaac.motion_generation-4.5.5] startup
# [3.515s] [ext: omni.kit.browser.core-2.2.1] startup
# [3.519s] [ext: omni.isaac.synthetic_utils-0.4.2] startup
# [3.529s] [ext: omni.isaac.universal_robots-0.3.1] startup
# [3.529s] [ext: omni.kit.browser.folder.core-1.7.1] startup
# [3.533s] [ext: omni.isaac.urdf-0.5.4] startup
# 2023-03-15 20:43:45 [3,531ms] [Warning] [omni.kit.menu.utils.scripts.builder_utils] ********************* MenuItemDescription URDF Importer *********************
# 2023-03-15 20:43:45 [3,531ms] [Warning] [omni.kit.menu.utils.scripts.builder_utils] URDF Importer uses onclick_fn and/or unclick_fn which are deprecated. Use onclick_action and unclick_action instead which use omni.kit.actions.core
# 2023-03-15 20:43:45 [3,532ms] [Warning] [omni.kit.menu.utils.scripts.builder_utils] ********************* MenuItemDescription Carter URDF *********************
# 2023-03-15 20:43:45 [3,532ms] [Warning] [omni.kit.menu.utils.scripts.builder_utils] Carter URDF uses onclick_fn and/or unclick_fn which are deprecated. Use onclick_action and unclick_action instead which use omni.kit.actions.core
# 2023-03-15 20:43:45 [3,536ms] [Warning] [omni.kit.menu.utils.scripts.builder_utils] ********************* MenuItemDescription Franka URDF *********************
# 2023-03-15 20:43:45 [3,536ms] [Warning] [omni.kit.menu.utils.scripts.builder_utils] Franka URDF uses onclick_fn and/or unclick_fn which are deprecated. Use onclick_action and unclick_action instead which use omni.kit.actions.core
# 2023-03-15 20:43:45 [3,540ms] [Warning] [omni.kit.menu.utils.scripts.builder_utils] ********************* MenuItemDescription Kaya URDF *********************
# 2023-03-15 20:43:45 [3,540ms] [Warning] [omni.kit.menu.utils.scripts.builder_utils] Kaya URDF uses onclick_fn and/or unclick_fn which are deprecated. Use onclick_action and unclick_action instead which use omni.kit.actions.core
# 2023-03-15 20:43:45 [3,544ms] [Warning] [omni.kit.menu.utils.scripts.builder_utils] ********************* MenuItemDescription UR10 URDF *********************
# 2023-03-15 20:43:45 [3,544ms] [Warning] [omni.kit.menu.utils.scripts.builder_utils] UR10 URDF uses onclick_fn and/or unclick_fn which are deprecated. Use onclick_action and unclick_action instead which use omni.kit.actions.core
# [3.554s] [ext: omni.isaac.utils-0.2.3] startup
# 2023-03-15 20:43:45 [3,551ms] [Warning] [omni.kit.menu.utils.scripts.builder_utils] ********************* MenuItemDescription UR3 *********************
# 2023-03-15 20:43:45 [3,551ms] [Warning] [omni.kit.menu.utils.scripts.builder_utils] UR3 uses onclick_fn and/or unclick_fn which are deprecated. Use onclick_action and unclick_action instead which use omni.kit.actions.core
# 2023-03-15 20:43:45 [3,551ms] [Warning] [omni.kit.menu.utils.scripts.builder_utils] ********************* MenuItemDescription UR5 *********************
# 2023-03-15 20:43:45 [3,551ms] [Warning] [omni.kit.menu.utils.scripts.builder_utils] UR5 uses onclick_fn and/or unclick_fn which are deprecated. Use onclick_action and unclick_action instead which use omni.kit.actions.core
# 2023-03-15 20:43:45 [3,551ms] [Warning] [omni.kit.menu.utils.scripts.builder_utils] ********************* MenuItemDescription UR10 *********************
# 2023-03-15 20:43:45 [3,551ms] [Warning] [omni.kit.menu.utils.scripts.builder_utils] UR10 uses onclick_fn and/or unclick_fn which are deprecated. Use onclick_action and unclick_action instead which use omni.kit.actions.core
# 2023-03-15 20:43:45 [3,551ms] [Warning] [omni.kit.menu.utils.scripts.builder_utils] ********************* MenuItemDescription UR3e *********************
# 2023-03-15 20:43:45 [3,551ms] [Warning] [omni.kit.menu.utils.scripts.builder_utils] UR3e uses onclick_fn and/or unclick_fn which are deprecated. Use onclick_action and unclick_action instead which use omni.kit.actions.core
# 2023-03-15 20:43:45 [3,551ms] [Warning] [omni.kit.menu.utils.scripts.builder_utils] ********************* MenuItemDescription UR5e *********************
# 2023-03-15 20:43:45 [3,551ms] [Warning] [omni.kit.menu.utils.scripts.builder_utils] UR5e uses onclick_fn and/or unclick_fn which are deprecated. Use onclick_action and unclick_action instead which use omni.kit.actions.core
# 2023-03-15 20:43:45 [3,551ms] [Warning] [omni.kit.menu.utils.scripts.builder_utils] ********************* MenuItemDescription UR10e *********************
# 2023-03-15 20:43:45 [3,551ms] [Warning] [omni.kit.menu.utils.scripts.builder_utils] UR10e uses onclick_fn and/or unclick_fn which are deprecated. Use onclick_action and unclick_action instead which use omni.kit.actions.core
# 2023-03-15 20:43:45 [3,551ms] [Warning] [omni.kit.menu.utils.scripts.builder_utils] ********************* MenuItemDescription UR16e *********************
# 2023-03-15 20:43:45 [3,551ms] [Warning] [omni.kit.menu.utils.scripts.builder_utils] UR16e uses onclick_fn and/or unclick_fn which are deprecated. Use onclick_action and unclick_action instead which use omni.kit.actions.core
# 2023-03-15 20:43:45 [3,551ms] [Warning] [omni.kit.menu.utils.scripts.builder_utils] ********************* MenuItemDescription Cobotta Pro 900 *********************
# 2023-03-15 20:43:45 [3,551ms] [Warning] [omni.kit.menu.utils.scripts.builder_utils] Cobotta Pro 900 uses onclick_fn and/or unclick_fn which are deprecated. Use onclick_action and unclick_action instead which use omni.kit.actions.core
# 2023-03-15 20:43:45 [3,551ms] [Warning] [omni.kit.menu.utils.scripts.builder_utils] ********************* MenuItemDescription Cobotta Pro 1300 *********************
# 2023-03-15 20:43:45 [3,551ms] [Warning] [omni.kit.menu.utils.scripts.builder_utils] Cobotta Pro 1300 uses onclick_fn and/or unclick_fn which are deprecated. Use onclick_action and unclick_action instead which use omni.kit.actions.core
# 2023-03-15 20:43:45 [3,551ms] [Warning] [omni.kit.menu.utils.scripts.builder_utils] ********************* MenuItemDescription Dofbot *********************
# 2023-03-15 20:43:45 [3,551ms] [Warning] [omni.kit.menu.utils.scripts.builder_utils] Dofbot uses onclick_fn and/or unclick_fn which are deprecated. Use onclick_action and unclick_action instead which use omni.kit.actions.core
# 2023-03-15 20:43:45 [3,551ms] [Warning] [omni.kit.menu.utils.scripts.builder_utils] ********************* MenuItemDescription Franka *********************
# 2023-03-15 20:43:45 [3,551ms] [Warning] [omni.kit.menu.utils.scripts.builder_utils] Franka uses onclick_fn and/or unclick_fn which are deprecated. Use onclick_action and unclick_action instead which use omni.kit.actions.core
# 2023-03-15 20:43:45 [3,551ms] [Warning] [omni.kit.menu.utils.scripts.builder_utils] ********************* MenuItemDescription A1 *********************
# 2023-03-15 20:43:45 [3,551ms] [Warning] [omni.kit.menu.utils.scripts.builder_utils] A1 uses onclick_fn and/or unclick_fn which are deprecated. Use onclick_action and unclick_action instead which use omni.kit.actions.core
# 2023-03-15 20:43:45 [3,551ms] [Warning] [omni.kit.menu.utils.scripts.builder_utils] ********************* MenuItemDescription Go1 *********************
# 2023-03-15 20:43:45 [3,551ms] [Warning] [omni.kit.menu.utils.scripts.builder_utils] Go1 uses onclick_fn and/or unclick_fn which are deprecated. Use onclick_action and unclick_action instead which use omni.kit.actions.core
# 2023-03-15 20:43:45 [3,551ms] [Warning] [omni.kit.menu.utils.scripts.builder_utils] ********************* MenuItemDescription ANYmal C *********************
# 2023-03-15 20:43:45 [3,551ms] [Warning] [omni.kit.menu.utils.scripts.builder_utils] ANYmal C uses onclick_fn and/or unclick_fn which are deprecated. Use onclick_action and unclick_action instead which use omni.kit.actions.core
# 2023-03-15 20:43:45 [3,551ms] [Warning] [omni.kit.menu.utils.scripts.builder_utils] ********************* MenuItemDescription ANYmal C *********************
# 2023-03-15 20:43:45 [3,551ms] [Warning] [omni.kit.menu.utils.scripts.builder_utils] ANYmal C uses onclick_fn and/or unclick_fn which are deprecated. Use onclick_action and unclick_action instead which use omni.kit.actions.core
# 2023-03-15 20:43:45 [3,551ms] [Warning] [omni.kit.menu.utils.scripts.builder_utils] ********************* MenuItemDescription Crazyflie *********************
# 2023-03-15 20:43:45 [3,551ms] [Warning] [omni.kit.menu.utils.scripts.builder_utils] Crazyflie uses onclick_fn and/or unclick_fn which are deprecated. Use onclick_action and unclick_action instead which use omni.kit.actions.core
# 2023-03-15 20:43:45 [3,551ms] [Warning] [omni.kit.menu.utils.scripts.builder_utils] ********************* MenuItemDescription Quadcopter *********************
# 2023-03-15 20:43:45 [3,551ms] [Warning] [omni.kit.menu.utils.scripts.builder_utils] Quadcopter uses onclick_fn and/or unclick_fn which are deprecated. Use onclick_action and unclick_action instead which use omni.kit.actions.core
# 2023-03-15 20:43:45 [3,551ms] [Warning] [omni.kit.menu.utils.scripts.builder_utils] ********************* MenuItemDescription Carter V1 *********************
# 2023-03-15 20:43:45 [3,551ms] [Warning] [omni.kit.menu.utils.scripts.builder_utils] Carter V1 uses onclick_fn and/or unclick_fn which are deprecated. Use onclick_action and unclick_action instead which use omni.kit.actions.core
# 2023-03-15 20:43:45 [3,551ms] [Warning] [omni.kit.menu.utils.scripts.builder_utils] ********************* MenuItemDescription Carter V2 *********************
# 2023-03-15 20:43:45 [3,551ms] [Warning] [omni.kit.menu.utils.scripts.builder_utils] Carter V2 uses onclick_fn and/or unclick_fn which are deprecated. Use onclick_action and unclick_action instead which use omni.kit.actions.core
# 2023-03-15 20:43:45 [3,551ms] [Warning] [omni.kit.menu.utils.scripts.builder_utils] ********************* MenuItemDescription Jetbot *********************
# 2023-03-15 20:43:45 [3,551ms] [Warning] [omni.kit.menu.utils.scripts.builder_utils] Jetbot uses onclick_fn and/or unclick_fn which are deprecated. Use onclick_action and unclick_action instead which use omni.kit.actions.core
# 2023-03-15 20:43:45 [3,551ms] [Warning] [omni.kit.menu.utils.scripts.builder_utils] ********************* MenuItemDescription Jetracer *********************
# 2023-03-15 20:43:45 [3,551ms] [Warning] [omni.kit.menu.utils.scripts.builder_utils] Jetracer uses onclick_fn and/or unclick_fn which are deprecated. Use onclick_action and unclick_action instead which use omni.kit.actions.core
# 2023-03-15 20:43:45 [3,551ms] [Warning] [omni.kit.menu.utils.scripts.builder_utils] ********************* MenuItemDescription Kaya *********************
# 2023-03-15 20:43:45 [3,551ms] [Warning] [omni.kit.menu.utils.scripts.builder_utils] Kaya uses onclick_fn and/or unclick_fn which are deprecated. Use onclick_action and unclick_action instead which use omni.kit.actions.core
# 2023-03-15 20:43:45 [3,551ms] [Warning] [omni.kit.menu.utils.scripts.builder_utils] ********************* MenuItemDescription Transporter *********************
# 2023-03-15 20:43:45 [3,551ms] [Warning] [omni.kit.menu.utils.scripts.builder_utils] Transporter uses onclick_fn and/or unclick_fn which are deprecated. Use onclick_action and unclick_action instead which use omni.kit.actions.core
# 2023-03-15 20:43:45 [3,551ms] [Warning] [omni.kit.menu.utils.scripts.builder_utils] ********************* MenuItemDescription Flat Grid *********************
# 2023-03-15 20:43:45 [3,551ms] [Warning] [omni.kit.menu.utils.scripts.builder_utils] Flat Grid uses onclick_fn and/or unclick_fn which are deprecated. Use onclick_action and unclick_action instead which use omni.kit.actions.core
# 2023-03-15 20:43:45 [3,551ms] [Warning] [omni.kit.menu.utils.scripts.builder_utils] ********************* MenuItemDescription Grid Room *********************
# 2023-03-15 20:43:45 [3,551ms] [Warning] [omni.kit.menu.utils.scripts.builder_utils] Grid Room uses onclick_fn and/or unclick_fn which are deprecated. Use onclick_action and unclick_action instead which use omni.kit.actions.core
# 2023-03-15 20:43:45 [3,551ms] [Warning] [omni.kit.menu.utils.scripts.builder_utils] ********************* MenuItemDescription Simple Room *********************
# 2023-03-15 20:43:45 [3,551ms] [Warning] [omni.kit.menu.utils.scripts.builder_utils] Simple Room uses onclick_fn and/or unclick_fn which are deprecated. Use onclick_action and unclick_action instead which use omni.kit.actions.core
# 2023-03-15 20:43:45 [3,551ms] [Warning] [omni.kit.menu.utils.scripts.builder_utils] ********************* MenuItemDescription Small Warehouse *********************
# 2023-03-15 20:43:45 [3,551ms] [Warning] [omni.kit.menu.utils.scripts.builder_utils] Small Warehouse uses onclick_fn and/or unclick_fn which are deprecated. Use onclick_action and unclick_action instead which use omni.kit.actions.core
# 2023-03-15 20:43:45 [3,551ms] [Warning] [omni.kit.menu.utils.scripts.builder_utils] ********************* MenuItemDescription Small Warehouse With Multiple Shelves *********************
# 2023-03-15 20:43:45 [3,551ms] [Warning] [omni.kit.menu.utils.scripts.builder_utils] Small Warehouse With Multiple Shelves uses onclick_fn and/or unclick_fn which are deprecated. Use onclick_action and unclick_action instead which use omni.kit.actions.core
# 2023-03-15 20:43:45 [3,551ms] [Warning] [omni.kit.menu.utils.scripts.builder_utils] ********************* MenuItemDescription Full Warehouse *********************
# 2023-03-15 20:43:45 [3,551ms] [Warning] [omni.kit.menu.utils.scripts.builder_utils] Full Warehouse uses onclick_fn and/or unclick_fn which are deprecated. Use onclick_action and unclick_action instead which use omni.kit.actions.core
# 2023-03-15 20:43:45 [3,551ms] [Warning] [omni.kit.menu.utils.scripts.builder_utils] ********************* MenuItemDescription Hospital *********************
# 2023-03-15 20:43:45 [3,551ms] [Warning] [omni.kit.menu.utils.scripts.builder_utils] Hospital uses onclick_fn and/or unclick_fn which are deprecated. Use onclick_action and unclick_action instead which use omni.kit.actions.core
# 2023-03-15 20:43:45 [3,551ms] [Warning] [omni.kit.menu.utils.scripts.builder_utils] ********************* MenuItemDescription Office *********************
# 2023-03-15 20:43:45 [3,551ms] [Warning] [omni.kit.menu.utils.scripts.builder_utils] Office uses onclick_fn and/or unclick_fn which are deprecated. Use onclick_action and unclick_action instead which use omni.kit.actions.core
# 2023-03-15 20:43:45 [3,551ms] [Warning] [omni.kit.menu.utils.scripts.builder_utils] ********************* MenuItemDescription tag36h11 *********************
# 2023-03-15 20:43:45 [3,551ms] [Warning] [omni.kit.menu.utils.scripts.builder_utils] tag36h11 uses onclick_fn and/or unclick_fn which are deprecated. Use onclick_action and unclick_action instead which use omni.kit.actions.core
# 2023-03-15 20:43:45 [3,551ms] [Warning] [omni.kit.menu.utils.scripts.builder_utils] ********************* MenuItemDescription Allegro Hand *********************
# 2023-03-15 20:43:45 [3,551ms] [Warning] [omni.kit.menu.utils.scripts.builder_utils] Allegro HaWarp 0.6.1 initialized:
#    CUDA Toolkit: 11.5, Driver: 11.7
#    Devices:
#      "cpu"    | x86_64
#      "cuda:0" | NVIDIA GeForce RTX 3060 (sm_86)
#    Kernel cache: /home/ksterx/.cache/warp/0.6.1
# nd uses onclick_fn and/or unclick_fn which are deprecated. Use onclick_action and unclick_action instead which use omni.kit.actions.core
# 2023-03-15 20:43:45 [3,551ms] [Warning] [omni.kit.menu.utils.scripts.builder_utils] ********************* MenuItemDescription Shadow Hand *********************
# 2023-03-15 20:43:45 [3,551ms] [Warning] [omni.kit.menu.utils.scripts.builder_utils] Shadow Hand uses onclick_fn and/or unclick_fn which are deprecated. Use onclick_action and unclick_action instead which use omni.kit.actions.core
# [3.559s] [ext: omni.kit.browser.sample-1.2.4] startup
# [3.560s] [ext: omni.graph.scriptnode-0.9.3] startup
# [3.562s] [ext: omni.command.usd-1.0.1] startup
# [3.566s] [ext: omni.warp-0.6.1] startup
# [3.788s] [ext: omni.kit.widget.live_session_management-1.1.3] startup
# [3.791s] [ext: omni.kit.hotkeys.core-1.0.8] startup
# [3.798s] [ext: omni.replicator.core-1.6.4] startup
# 2023-03-15 20:43:46 [3,880ms] [Warning] [omni.replicator.core.scripts.annotators] Annotator PostProcessDispatch is already registered, overwriting annotator template
# [3.919s] [ext: omni.kit.widget.highlight_label-1.0.0] startup
# [3.919s] [ext: omni.kit.widget.layers-1.6.9] startup
# [3.930s] [ext: omni.isaac.core_nodes-0.21.0] startup
# [3.940s] [ext: omni.kit.actions.window-1.1.0] startup
# [3.945s] [ext: omni.isaac.debug_draw-0.2.2] startup
# [3.950s] [ext: omni.kit.property.layer-1.1.3] startup
# [3.952s] [ext: omni.isaac.wheeled_robots-0.6.1] startup
# [3.963s] [ext: omni.kit.hotkeys.window-1.1.3] startup
# [3.967s] [ext: omni.isaac.occupancy_map-0.2.6] startup
# 2023-03-15 20:43:46 [3,966ms] [Warning] [omni.kit.menu.utils.scripts.builder_utils] ********************* MenuItemDescription Occupancy Map *********************
# 2023-03-15 20:43:46 [3,966ms] [Warning] [omni.kit.menu.utils.scripts.builder_utils] Occupancy Map uses onclick_fn and/or unclick_fn which are deprecated. Use onclick_action and unclick_action instead which use omni.kit.actions.core
# 2023-03-15 20:43:46 [3,969ms] [Warning] [omni.kit.menu.utils.scripts.builder_utils] ********************* MenuItemDescription Block World Generator *********************
# 2023-03-15 20:43:46 [3,969ms] [Warning] [omni.kit.menu.utils.scripts.builder_utils] Block World Generator uses onclick_fn and/or unclick_fn which are deprecated. Use onclick_action and unclick_action instead which use omni.kit.actions.core
# [3.978s] [ext: omni.kit.property.audio-1.0.6] startup
# [3.979s] [ext: omni.kit.property.camera-1.0.3] startup
# [3.980s] [ext: omni.kit.property.geometry-1.2.2] startup
# [3.982s] [ext: omni.kit.widget.stage_icons-1.0.2] startup
# [3.983s] [ext: omni.kit.property.light-1.0.6] startup
# [3.983s] [ext: omni.kit.property.material-1.8.16] startup
# [3.985s] [ext: omni.hydra.scene_api-0.1.1] startup
# [3.991s] [ext: omni.kit.window.stage-2.3.11] startup
# [3.994s] [ext: omni.kit.property.render-1.1.0] startup
# [3.995s] [ext: omni.kit.property.skel-1.0.1] startup
# [3.995s] [ext: omni.kit.property.transform-1.3.4] startup
# [3.998s] [ext: omni.kit.menu.stage-1.2.1] startup
# [3.998s] [ext: omni.kit.manipulator.transform-104.6.11] startup
# [4.002s] [ext: omni.kit.profiler.window-2.0.4] startup
# [4.089s] [ext: omni.kit.property.bundle-1.2.6] startup
# [4.090s] [ext: omni.kit.manipulator.selector-1.0.1] startup
# [4.091s] [ext: omni.kit.manipulator.tool.snap-1.2.2] startup
# [4.095s] [ext: omni.kit.window.toolbar-1.3.3] startup
# [4.101s] [ext: omni.kit.property.isaac-0.1.1] startup
# [4.102s] [ext: omni.kit.stage_column.payload-1.0.8] startup
# [4.104s] [ext: omni.kit.manipulator.camera-104.0.22] startup
# [4.104s] [ext: omni.kit.manipulator.prim-104.10.5] startup
# [4.109s] [ext: omni.kit.manipulator.selection-104.0.6] startup
# [4.109s] [ext: omni.kit.viewport.menubar.camera-104.1.7] startup
# [4.114s] [ext: omni.kit.viewport.menubar.render-104.0.19] startup
# [4.116s] [ext: omni.kit.viewport.menubar.display-104.1.11] startup
# [4.118s] [ext: omni.physx.commands-104.1.6-5.1] startup
# [4.122s] [ext: omni.kit.viewport.menubar.settings-104.3.4] startup
# [4.126s] [ext: omni.rtx.window.settings-0.6.2] startup
# [4.132s] [ext: omni.kit.stage_column.variant-1.0.9] startup
# [4.133s] [ext: omni.physx.ui-104.1.6-5.1] startup
# [4.179s] [ext: omni.kit.viewport.bundle-104.0.2] startup
# [4.179s] [ext: omni.hydra.pxr.settings-1.0.3] startup
# [4.180s] [ext: omni.kit.viewport.menubar.lighting-104.0.8] startup
# [4.182s] [ext: omni.kit.property.physx-0.1.0] startup
# [4.215s] [ext: omni.physx.demos-104.1.6-5.1] startup
# [4.219s] [ext: omni.kit.viewport.pxr-104.0.1] startup
# [4.219s] [ext: omni.kit.viewport.ready-1.0.2] startup
# [4.220s] [ext: omni.kit.viewport.rtx-104.0.0] startup
# [4.220s] [ext: omni.physx.camera-104.1.6-5.1] startup
# [4.228s] [ext: omni.kit.selection-0.1.0] startup
# [4.229s] [ext: omni.physx.cct-104.1.6-5.1] startup
# [4.525s] [ext: omni.physx.supportui-104.1.6-5.1] startup
# [4.591s] [ext: omni.kit.widget.live-2.0.3] startup
# [4.593s] [ext: omni.physx.vehicle-104.1.6-5.1] startup
# [4.603s] [ext: omni.kit.menu.edit-1.1.5] startup
# 2023-03-15 20:43:46 [4,597ms] [Warning] [omni.kit.menu.utils.scripts.builder_utils] ********************* MenuItemDescription Toggle Grid Visibility *********************
# 2023-03-15 20:43:46 [4,597ms] [Warning] [omni.kit.menu.utils.scripts.builder_utils] Toggle Grid Visibility uses onclick_fn and/or unclick_fn which are deprecated. Use onclick_action and unclick_action instead which use omni.kit.actions.core
# 2023-03-15 20:43:46 [4,597ms] [Warning] [omni.kit.menu.utils.scripts.builder_utils] ********************* MenuItemDescription Toggle Camera Visibility *********************
# 2023-03-15 20:43:46 [4,597ms] [Warning] [omni.kit.menu.utils.scripts.builder_utils] Toggle Camera Visibility uses onclick_fn and/or unclick_fn which are deprecated. Use onclick_action and unclick_action instead which use omni.kit.actions.core
# 2023-03-15 20:43:46 [4,597ms] [Warning] [omni.kit.menu.utils.scripts.builder_utils] ********************* MenuItemDescription Toggle Light Visibility *********************
# 2023-03-15 20:43:46 [4,597ms] [Warning] [omni.kit.menu.utils.scripts.builder_utils] Toggle Light Visibility uses onclick_fn and/or unclick_fn which are deprecated. Use onclick_action and unclick_action instead which use omni.kit.actions.core
# [4.604s] [ext: omni.kit.window.commands-0.2.4] startup
# [4.606s] [ext: omni.kit.window.console-0.2.3] startup
# [4.614s] [ext: omni.physx.bundle-104.1.6-5.1] startup
# [4.614s] [ext: omni.graph.bundle.action-1.3.0] startup
# [4.614s] [ext: omni.isaac.range_sensor-0.7.0] startup
# 2023-03-15 20:43:46 [4,613ms] [Warning] [omni.kit.menu.utils.scripts.builder_utils] ********************* MenuItemDescription Rotating *********************
# 2023-03-15 20:43:46 [4,613ms] [Warning] [omni.kit.menu.utils.scripts.builder_utils] Rotating uses onclick_fn and/or unclick_fn which are deprecated. Use onclick_action and unclick_action instead which use omni.kit.actions.core
# 2023-03-15 20:43:46 [4,613ms] [Warning] [omni.kit.menu.utils.scripts.builder_utils] ********************* MenuItemDescription Generic *********************
# 2023-03-15 20:43:46 [4,613ms] [Warning] [omni.kit.menu.utils.scripts.builder_utils] Generic uses onclick_fn and/or unclick_fn which are deprecated. Use onclick_action and unclick_action instead which use omni.kit.actions.core
# 2023-03-15 20:43:46 [4,613ms] [Warning] [omni.kit.menu.utils.scripts.builder_utils] ********************* MenuItemDescription Array *********************
# 2023-03-15 20:43:46 [4,613ms] [Warning] [omni.kit.menu.utils.scripts.builder_utils] Array uses onclick_fn and/or unclick_fn which are deprecated. Use onclick_action and unclick_action instead which use omni.kit.actions.core
# 2023-03-15 20:43:46 [4,613ms] [Warning] [omni.kit.menu.utils.scripts.builder_utils] ********************* MenuItemDescription Emitter *********************
# 2023-03-15 20:43:46 [4,613ms] [Warning] [omni.kit.menu.utils.scripts.builder_utils] Emitter uses onclick_fn and/or unclick_fn which are deprecated. Use onclick_action and unclick_action instead which use omni.kit.actions.core
# 2023-03-15 20:43:46 [4,613ms] [Warning] [omni.kit.menu.utils.scripts.builder_utils] ********************* MenuItemDescription FiringGroup *********************
# 2023-03-15 20:43:46 [4,613ms] [Warning] [omni.kit.menu.utils.scripts.builder_utils] FiringGroup uses onclick_fn and/or unclick_fn which are deprecated. Use onclick_action and unclick_action instead which use omni.kit.actions.core
# 2023-03-15 20:43:46 [4,614ms] [Warning] [omni.kit.menu.utils.scripts.builder_utils] ********************* MenuItemDescription LIDAR *********************
# 2023-03-15 20:43:46 [4,614ms] [Warning] [omni.kit.menu.utils.scripts.builder_utils] LIDAR uses onclick_fn and/or unclick_fn which are deprecated. Use onclick_action and unclick_action instead which use omni.kit.actions.core
# 2023-03-15 20:43:46 [4,618ms] [Warning] [omni.kit.menu.utils.scripts.builder_utils] ********************* MenuItemDescription Ultrasonic *********************
# 2023-03-15 20:43:46 [4,618ms] [Warning] [omni.kit.menu.utils.scripts.builder_utils] Ultrasonic uses onclick_fn and/or unclick_fn which are deprecated. Use onclick_action and unclick_action instead which use omni.kit.actions.core
# 2023-03-15 20:43:46 [4,623ms] [Warning] [omni.kit.menu.utils.scripts.builder_utils] ********************* MenuItemDescription Generic Range Sensor *********************
# 2023-03-15 20:43:46 [4,623ms] [Warning] [omni.kit.menu.utils.scripts.builder_utils] Generic Range Sensor uses onclick_fn and/or unclick_fn which are deprecated. Use onclick_action and unclick_action instead which use omni.kit.actions.core
# [4.638s] [ext: omni.kit.window.script_editor-1.6.4] startup
# [4.648s] [ext: omni.kit.window.status_bar-0.1.5] startup
# [4.652s] [ext: omni.kit.window.title-1.1.2] startup
# [4.653s] [ext: omni.replicator.composer-1.2.2] startup
# [4.666s] [ext: omni.replicator.isaac-1.7.3] startup
# [4.681s] [ext: omni.isaac.kit-1.2.1] startup
# [4.681s] [ext: omni.isaac.sensor-5.3.1] startup
# 2023-03-15 20:43:46 [4,674ms] [Warning] [omni.ext.plugin] [ext: omni.isaac.sensor-5.3.1] Native plugin search dir contains several files: /home/ksterx/.local/share/ov/pkg/isaac_sim-2022.2.0/exts/omni.isaac.sensor/bin . It makes dir walk slow, replace with the exact path to the plugin instead of a wildcard.
# 2023-03-15 20:43:46 [4,724ms] [Warning] [omni.kit.menu.utils.scripts.builder_utils] ********************* MenuItemDescription Contact Sensor *********************
# 2023-03-15 20:43:46 [4,724ms] [Warning] [omni.kit.menu.utils.scripts.builder_utils] Contact Sensor uses onclick_fn and/or unclick_fn which are deprecated. Use onclick_action and unclick_action instead which use omni.kit.actions.core
# 2023-03-15 20:43:46 [4,724ms] [Warning] [omni.kit.menu.utils.scripts.builder_utils] ********************* MenuItemDescription Imu Sensor *********************
# 2023-03-15 20:43:46 [4,724ms] [Warning] [omni.kit.menu.utils.scripts.builder_utils] Imu Sensor uses onclick_fn and/or unclick_fn which are deprecated. Use onclick_action and unclick_action instead which use omni.kit.actions.core
# 2023-03-15 20:43:46 [4,724ms] [Warning] [omni.kit.menu.utils.scripts.builder_utils] ********************* MenuItemDescription Rotating *********************
# 2023-03-15 20:43:46 [4,724ms] [Warning] [omni.kit.menu.utils.scripts.builder_utils] Rotating uses onclick_fn and/or unclick_fn which are deprecated. Use onclick_action and unclick_action instead which use omni.kit.actions.core
# 2023-03-15 20:43:46 [4,724ms] [Warning] [omni.kit.menu.utils.scripts.builder_utils] ********************* MenuItemDescription Solid State *********************
# 2023-03-15 20:43:46 [4,724ms] [Warning] [omni.kit.menu.utils.scripts.builder_utils] Solid State uses onclick_fn and/or unclick_fn which are deprecated. Use onclick_action and unclick_action instead which use omni.kit.actions.core
# 2023-03-15 20:43:46 [4,727ms] [Warning] [omni.kit.menu.utils.scripts.builder_utils] ********************* MenuItemDescription Contact *********************
# 2023-03-15 20:43:46 [4,727ms] [Warning] [omni.kit.menu.utils.scripts.builder_utils] Contact uses onclick_fn and/or unclick_fn which are deprecated. Use onclick_action and unclick_action instead which use omni.kit.actions.core
# 2023-03-15 20:43:46 [4,727ms] [Warning] [omni.kit.menu.utils.scripts.builder_utils] ********************* MenuSaving a temp livesync stage at  omniverse://localhost/Users/ksterx/temp_jupyter_stage.usd  ...Done.
# [6.746s] RTX ready
# [6.746s] RTX ready

# %%
from omni.isaac.core.utils.stage import add_reference_to_stage
from omni.isaac.core import SimulationContext

# %%
from omni.isaac.core import World
from omni.isaac.core.objects import DynamicCuboid
from omni.isaac.core.robots import Robot
from omni.isaac.core.utils.nucleus import get_assets_root_path



world = World(stage_units_in_meters=1.0)
world.scene.add_default_ground_plane()
world.render()
# A render/ step or an update call is needed to reflect the changes to the opened USD in Isaac Sim GUI
#  Note: avoid pressing play/ pause or stop in the GUI in this workflow.

# %%
world

# %%
world.scene.GetPrimAtPath
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_159247/3412139381.py in <module>
# ----> 1 world.scene.GetPrimAtPath
#
# AttributeError: 'Scene' object has no attribute 'GetPrimAtPath'
